# %%
import numpy as np

dets = np.array([
    [0, 0, 10, 10, 0.9],
    [1, 1, 9, 9, 1],
    [4, 4, 5, 5, 0.8],
    [1, 2, 3, 5, 0.6],
    [1, 2, 3, 4, 0.5]],
    dtype=np.float32)
thresh = 0.6

# %%
x1 = dets[:,0]
y1 = dets[:,1]
x2 = dets[:,2]
y2 = dets[:,3]
score = dets[:,4]

# %%
# This is an easier way to implement
#num_of_rows = np.size( dets, 0 )
#print( num_of_rows )
#for i in range( num_of_rows ):
#    for j in range(i+1, num_of_rows):
#      print(i, ",", j)
#
# But a more elegant way of implementing this is to use the NP's arrays
# Out:
# 5
# 0 , 1
# 0 , 2
# 0 , 3
# 0 , 4
# 1 , 2
# 1 , 3
# 1 , 4
# 2 , 3
# 2 , 4
# 3 , 4

# %%
def iou(region1, region2):
  pass

# %%
def nms(dets, thresh):
    num_of_rows = np.size( dets, 0 )
    print( num_of_rows )
    
    
    
    for i in range( num_of_rows ):
      for j in range(i+1, num_of_rows):
        print(i, ",", j)

# %%
idxs = nms(dets, thresh)
print(idxs)
print(dets[idxs])
