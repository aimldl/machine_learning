# %% [markdown]
# * [[인터뷰] 데이콘 김국진 대표, AI 컴피티션 플랫폼이란?](https://www.aitimes.kr/news/articleView.html?idxno=16072), 2020-04-16, AI Times
# * [Top Competitive Data Science Platforms other than Kaggle](https://towardsdatascience.com/top-competitive-data-science-platforms-other-than-kaggle-2995e9dad93c), 2019-04-07, towards data science

# %% [markdown]
# * Kaggle
# * DrivenData
# * CrowdAnalytics
# * CodaLab
# * KDD
